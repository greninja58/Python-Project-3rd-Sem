# %%
import pandas as pd

# %%
import random

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
plt.style.use('bmh')

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
s=pd.read_csv('Students.csv')

# %%
type(s)
# Out:
# pandas.core.frame.DataFrame

# %%
s
# Out:
#   Name  Physics  Maths  Chemistry  Total
# 0    A       54     34         45    133
# 1    B       35     55         25     95
# 2    C       43     54         34    131
# 3    D       44     15         35    134
# 4    E       73     67         86    226
# 5    F       76     64         44    184
# 6    G       35     86         34    155
# 7    H       63     36         64    173
# 8    I       43     43         64    150

# %%
s.Chemistry
# Out:
# 0    45
# 1    25
# 2    34
# 3    35
# 4    86
# 5    44
# 6    34
# 7    64
# 8    64
# Name: Chemistry, dtype: int64

# %%
s.Maths
# Out:
# 0    34
# 1    55
# 2    54
# 3    15
# 4    67
# 5    64
# 6    86
# 7    36
# 8    43
# Name: Maths, dtype: int64

# %%
s.Physics
# Out:
# 0    54
# 1    35
# 2    43
# 3    44
# 4    73
# 5    76
# 6    35
# 7    63
# 8    43
# Name: Physics, dtype: int64

# %%
a=s.Physics*100/s.Physics.iloc[6]
b=s.Chemistry*100/s.Chemistry.iloc[1]
c=s.Maths*100/s.Maths.iloc[0]

# %%
plt.bar(s.Name,s.Total,label='Total')
plt.plot(s.Name,a,':',label='Physics')
plt.plot(s.Name,b,'--',label='Chemistry')
plt.plot(s.Name,c,'-.',label='Maths')

plt.legend()
plt.show()

# %%
print(s.cov())
plt.plot(s.cov())
# Out:
#               Physics       Maths   Chemistry        Total
# Physics    243.194444   14.736111  198.347222   473.361111
# Maths       14.736111  443.277778   10.305556   261.652778
# Chemistry  198.347222   10.305556  383.861111   605.430556
# Total      473.361111  261.652778  605.430556  1413.777778
# [<matplotlib.lines.Line2D at 0x1f4224395d0>,
#  <matplotlib.lines.Line2D at 0x1f422439570>,
#  <matplotlib.lines.Line2D at 0x1f4224395a0>,
#  <matplotlib.lines.Line2D at 0x1f422439720>]

# %%
print(s.corr())
plt.plot(s.corr())
# Out:
#             Physics     Maths  Chemistry     Total
# Physics    1.000000  0.044882   0.649176  0.807282
# Maths      0.044882  1.000000   0.024983  0.330519
# Chemistry  0.649176  0.024983   1.000000  0.821839
# Total      0.807282  0.330519   0.821839  1.000000
# [<matplotlib.lines.Line2D at 0x1f4224a2380>,
#  <matplotlib.lines.Line2D at 0x1f4224a2320>,
#  <matplotlib.lines.Line2D at 0x1f4224a2350>,
#  <matplotlib.lines.Line2D at 0x1f4224a24d0>]

# %%
ns=s.drop("Total",axis=1)
ns
# Out:
#   Name  Physics  Maths  Chemistry
# 0    A       54     34         45
# 1    B       35     55         25
# 2    C       43     54         34
# 3    D       44     15         35
# 4    E       73     67         86
# 5    F       76     64         44
# 6    G       35     86         34
# 7    H       63     36         64
# 8    I       43     43         64

# %%
ns=s.drop("Total",axis=1)
ns
# Out:
#   Name  Physics  Maths  Chemistry
# 0    A       54     34         45
# 1    B       35     55         25
# 2    C       43     54         34
# 3    D       44     15         35
# 4    E       73     67         86
# 5    F       76     64         44
# 6    G       35     86         34
# 7    H       63     36         64
# 8    I       43     43         64

# %%
mode=3*(ns.median())-2*(ns.mean())
mode
# Out:
# Physics      28.444444
# Maths        61.111111
# Chemistry    36.222222
# dtype: float64

# %%
plt.plot(ns.mean(),label='Mean')
plt.plot(ns.median(),label='Median')
plt.plot(mode,label='Mode')
plt.legend()

# %%
print("The Highest marks in each subject are")
s[['Physics','Chemistry','Maths']].max(0)
# Out:
# The Highest marks in each subject are
# Physics      76
# Chemistry    86
# Maths        86
# dtype: int64

# %%
print("The Highest marks in each subject are")
s[['Physics','Chemistry','Maths']].min(0)
# Out:
# The Highest marks in each subject are
# Physics      35
# Chemistry    25
# Maths        15
# dtype: int64

# %%
print("The Highest marks for each student in a subject are")
s[['Physics','Chemistry','Maths']].max(1)
# Out:
# The Highest marks for each student in a subject are
# 0    54
# 1    55
# 2    54
# 3    44
# 4    86
# 5    76
# 6    86
# 7    64
# 8    64
# dtype: int64

# %%
print("The Highest marks for each student in a subject are")
s[['Physics','Chemistry','Maths']].min(1)
# Out:
# The Highest marks for each student in a subject are
# 0    34
# 1    25
# 2    34
# 3    15
# 4    67
# 5    44
# 6    34
# 7    36
# 8    43
# dtype: int64

# %%
plt.plot(ns.quantile())

# %%
print(ns.quantile())
# Out:
# Physics      44.0
# Maths        54.0
# Chemistry    44.0
# Name: 0.5, dtype: float64

# %%
s.rank()
# Out:
#    Name  Physics  Maths  Chemistry  Total
# 0   1.0      6.0    2.0        6.0    3.0
# 1   2.0      1.5    6.0        1.0    1.0
# 2   3.0      3.5    5.0        2.5    2.0
# 3   4.0      5.0    1.0        4.0    4.0
# 4   5.0      8.0    8.0        9.0    9.0
# 5   6.0      9.0    7.0        5.0    8.0
# 6   7.0      1.5    9.0        2.5    6.0
# 7   8.0      7.0    3.0        7.5    7.0
# 8   9.0      3.5    4.0        7.5    5.0
